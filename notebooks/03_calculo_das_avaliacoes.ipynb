# %% [markdown]
# # 03 - Calculo das Avaliacoes
#
# Calcula as metricas de avaliacao das segmentacoes binarizadas e persiste os resultados no SQLite do projeto.
#
# ## Imports
#
# Carrega o controller responsavel por executar a etapa de avaliacao.

# %%
import sys
from pathlib import Path

root_dir = Path.cwd()
if not (root_dir / 'src').exists() and (root_dir.parent / 'src').exists():
    root_dir = root_dir.parent

if str(root_dir) not in sys.path:
    sys.path.insert(0, str(root_dir))

from src.controllers import AvaliacaoController

# %% [markdown]
# ## Configuracao
#
# Usa a configuracao padrao do projeto para ler o SQLite e localizar as mascaras binarizadas.

# %%
avaliacao_controller = AvaliacaoController()

# %% [markdown]
# ## Calculo das metricas
#
# Executa a avaliacao por imagem, com logs de progresso e persistencia incremental no SQLite.

# %%
stats = avaliacao_controller.processar_imagens()
stats
# Out:
# Calculando metricas de avaliacao
# [AVALIACAO] 1/387 | 0266d87e-faec-497f-8e14-949a5ab6afa3 | processadas=1/387 (  0.3%) | ok=1 skip=0 erro=0 | media=22.79s/img | ETA 2h26m35s
# [AVALIACAO] 2/387 | 034d9e54-2983-466e-9a2b-19cb0f638536 | processadas=2/387 (  0.5%) | ok=2 skip=0 erro=0 | media=22.61s/img | ETA 2h25m04s
# [AVALIACAO] 3/387 | 05a68a22-1729-42ea-8883-e6b90dd8a789 | processadas=3/387 (  0.8%) | ok=3 skip=0 erro=0 | media=22.44s/img | ETA 2h23m35s
# [AVALIACAO] 4/387 | 069d2cff-0b33-42bc-b85e-a4b740860bc1 | processadas=4/387 (  1.0%) | ok=4 skip=0 erro=0 | media=21.74s/img | ETA 2h18m45s
# [AVALIACAO] 5/387 | 0831a96e-316e-4041-9025-4d30c31eb021 | processadas=5/387 (  1.3%) | ok=5 skip=0 erro=0 | media=17.70s/img | ETA 1h52m40s
# [AVALIACAO] 6/387 | 0bfd53d9-1efc-44a4-b8e7-09bb28b556ef | processadas=6/387 (  1.6%) | ok=6 skip=0 erro=0 | media=18.13s/img | ETA 1h55m06s
# [AVALIACAO] 7/387 | 1015_Calcula_515 | processadas=7/387 (  1.8%) | ok=7 skip=0 erro=0 | media=15.66s/img | ETA 1h39m10s
# [AVALIACAO] 8/387 | 101_Calcula_576 | processadas=8/387 (  2.1%) | ok=8 skip=0 erro=0 | media=13.75s/img | ETA 1h26m49s
# [AVALIACAO] 9/387 | 1028_Calcula_483 | processadas=9/387 (  2.3%) | ok=9 skip=0 erro=0 | media=12.29s/img | ETA 1h17m26s
# [AVALIACAO] 10/387 | 1042_Calcula_494 | processadas=10/387 (  2.6%) | ok=10 skip=0 erro=0 | media=11.21s/img | ETA 1h10m27s
# [AVALIACAO] 11/387 | 104_Calcula_631 | processadas=11/387 (  2.8%) | ok=11 skip=0 erro=0 | media=10.23s/img | ETA 1h04m06s
# [AVALIACAO] 12/387 | 1068_Calcula_480 | processadas=12/387 (  3.1%) | ok=12 skip=0 erro=0 | media=9.44s/img | ETA 58m58s
# [AVALIACAO] 13/387 | 1074_Calcula_465 | processadas=13/387 (  3.4%) | ok=13 skip=0 erro=0 | media=8.75s/img | ETA 54m31s
# [AVALIACAO] 55/387 | 1199_Calcula_422 | processadas=55/387 ( 14.2%) | ok=55 skip=0 erro=0 | media=3.64s/img | ETA 20m08s
# [AVALIACAO] 56/387 | 119_Calcula_544 | processadas=56/387 ( 14.5%) | ok=56 skip=0 erro=0 | media=3.60s/img | ETA 19m51s
# [AVALIACAO] 57/387 | 11_Calcula_665 | processadas=57/387 ( 14.7%) | ok=57 skip=0 erro=0 | media=3.56s/img | ETA 19m33s
# [AVALIACAO] 58/387 | 1200_Calcula_455 | processadas=58/387 ( 15.0%) | ok=58 skip=0 erro=0 | media=3.50s/img | ETA 19m12s
# [AVALIACAO] 59/387 | 1206_Calcula_439 | processadas=59/387 ( 15.2%) | ok=59 skip=0 erro=0 | media=3.45s/img | ETA 18m52s
# [AVALIACAO] 60/387 | 120_Calcula_559 | processadas=60/387 ( 15.5%) | ok=60 skip=0 erro=0 | media=3.41s/img | ETA 18m34s
# [AVALIACAO] 61/387 | 1211_Calcula_395 | processadas=61/387 ( 15.8%) | ok=61 skip=0 erro=0 | media=3.36s/img | ETA 18m15s
# [AVALIACAO] 62/387 | 1213_Calcula_572 | processadas=62/387 ( 16.0%) | ok=62 skip=0 erro=0 | media=3.32s/img | ETA 17m58s
# [AVALIACAO] 63/387 | 121_Calcula_500 | processadas=63/387 ( 16.3%) | ok=63 skip=0 erro=0 | media=3.29s/img | ETA 17m44s
# [AVALIACAO] 64/387 | 1221_Calcula_452 | processadas=64/387 ( 16.5%) | ok=64 skip=0 erro=0 | media=3.24s/img | ETA 17m26s
# [AVALIACAO] 65/387 | 1234_Calcula_462 | processadas=65/387 ( 16.8%) | ok=65 skip=0 erro=0 | media=3.21s/img | ETA 17m14s
# [AVALIACAO] 66/387 | 123_Calcula_535 | processadas=66/387 ( 17.1%) | ok=66 skip=0 erro=0 | media=3.17s/img | ETA 16m59s
# [AVALIACAO] 67/387 | 123e681e-0fcd-4138-8212-b85901c9f5fc | processadas=67/387 ( 17.3%) | ok=67 skip=0 erro=0 | media=3.56s/img | ETA 18m59s
# [AVALIACAO] 68/387 | 1242_Calcula_448 | processadas=68/387 ( 17.6%) | ok=68 skip=0 erro=0 | media=3.52s/img | ETA 18m42s
# [AVALIACAO] 69/387 | 1252_Calcula_455 | processadas=69/387 ( 17.8%) | ok=69 skip=0 erro=0 | media=3.47s/img | ETA 18m24s
# [AVALIACAO] 70/387 | 1254_Calcula_496 | processadas=70/387 ( 18.1%) | ok=70 skip=0 erro=0 | media=3.43s/img | ETA 18m07s
# [AVALIACAO] 71/387 | 1258_Calcula_450 | processadas=71/387 ( 18.3%) | ok=71 skip=0 erro=0 | media=3.39s/img | ETA 17m49s
# [AVALIACAO] 72/387 | 1260_Calcula_447 | processadas=72/387 ( 18.6%) | ok=72 skip=0 erro=0 | media=3.35s/img | ETA 17m36s
# [AVALIACAO] 73/387 | 1263_Calcula_474 | processadas=73/387 ( 18.9%) | ok=73 skip=0 erro=0 | media=3.32s/img | ETA 17m22s
# [AVALIACAO] 74/387 | 1266_Calcula_492 | processadas=74/387 ( 19.1%) | ok=74 skip=0 erro=0 | media=3.28s/img | ETA 17m06s
# [AVALIACAO] 75/387 | 126_Calcula_514 | processadas=75/387 ( 19.4%) | ok=75 skip=0 erro=0 | media=3.25s/img | ETA 16m55s
# [AVALIACAO] 76/387 | 1270_Calcula_457 | processadas=76/387 ( 19.6%) | ok=76 skip=0 erro=0 | media=3.21s/img | ETA 16m39s
# [AVALIACAO] 77/387 | 1274_Calcula_425 | processadas=77/387 ( 19.9%) | ok=77 skip=0 erro=0 | media=3.18s/img | ETA 16m25s
# [AVALIACAO] 78/387 | 1280_Calcula_346 | processadas=78/387 ( 20.2%) | ok=78 skip=0 erro=0 | media=3.15s/img | ETA 16m12s
# [AVALIACAO] 79/387 | 1284_Calcula_423 | processadas=79/387 ( 20.4%) | ok=79 skip=0 erro=0 | media=3.11s/img | ETA 15m58s
# [AVALIACAO] 80/387 | 1286_Calcula_494 | processadas=80/387 ( 20.7%) | ok=80 skip=0 erro=0 | media=3.09s/img | ETA 15m47s
# [AVALIACAO] 81/387 | 128_Calcula_556 | processadas=81/387 ( 20.9%) | ok=81 skip=0 erro=0 | media=3.06s/img | ETA 15m37s
# [AVALIACAO] 82/387 | 1290_Calcula_457 | processadas=82/387 ( 21.2%) | ok=82 skip=0 erro=0 | media=3.04s/img | ETA 15m26s
# [AVALIACAO] 83/387 | 1291_Calcula_404 | processadas=83/387 ( 21.4%) | ok=83 skip=0 erro=0 | media=3.01s/img | ETA 15m15s
# [AVALIACAO] 84/387 | 129_Calcula_487 | processadas=84/387 ( 21.7%) | ok=84 skip=0 erro=0 | media=2.99s/img | ETA 15m06s
# [AVALIACAO] 85/387 | 12_Calcula_589 | processadas=85/387 ( 22.0%) | ok=85 skip=0 erro=0 | media=2.97s/img | ETA 14m57s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 stats = avaliacao_controller.processar_imagens()
#       2 stats
#
# File ~/projeto-bufalos/worktrees/auprc-binarizacao/src/controllers/avaliacao_controller.py:118, in AvaliacaoController.processar_imagens(self, imagens)
#     116 inicio = time.perf_counter()
#     117 try:
# --> 118     self.processar_imagem(
#     119         imagem=imagem,
#     120     )
#     121 except Exception as exc:
#     122     stats.registrar_erro()
#
# File ~/projeto-bufalos/worktrees/auprc-binarizacao/src/controllers/avaliacao_controller.py:82, in AvaliacaoController.processar_imagem(self, imagem)
#      65 mascaras_modelo = {
#      66     nome_modelo: carregar_mask_array_avaliacao(
#      67         imagem.nome_arquivo,
#    (...)     71     for nome_modelo in nomes_modelo
#      72 }
#      73 score_masks_modelo = {
#      74     nome_modelo: carregar_score_mask_predita(
#      75         imagem.nome_arquivo,
#    (...)     79     for nome_modelo in nomes_modelo
#      80 }
# ---> 82 imagem_avaliada = self.avaliacao_service.avaliar(
#      83     imagem=imagem,
#      84     ground_truth_mask=ground_truth_mask,
#      85     mascaras_modelo=mascaras_modelo,
#      86     score_masks_modelo=score_masks_modelo,
#      87 )
#      88 ground_truth = imagem_avaliada.ground_truth_binarizada
#      89 if ground_truth is not None:
#
# File ~/projeto-bufalos/worktrees/auprc-binarizacao/src/services/avaliacao_service.py:40, in AvaliacaoService.avaliar(self, imagem, ground_truth_mask, mascaras_modelo, score_masks_modelo)
#      35 segmentacoes = {
#      36     segmentacao.nome_modelo: segmentacao
#      37     for segmentacao in imagem.segmentacoes
#      38 }
#      39 for nome_modelo, mask_modelo in mascaras_modelo.items():
# ---> 40     segmentacoes[nome_modelo] = self._avaliar_modelo(
#      41         imagem.nome_arquivo,
#      42         nome_modelo,
#      43         ground_truth_mask,
#      44         mask_modelo,
#      45         score_masks_modelo[nome_modelo],
#      46         segmentacoes.get(nome_modelo),
#      47     )
#      49 imagem.segmentacoes = sorted(
#      50     segmentacoes.values(),
#      51     key=lambda segmentacao: segmentacao.nome_modelo,
#      52 )
#      53 return imagem
#
# File ~/projeto-bufalos/worktrees/auprc-binarizacao/src/services/avaliacao_service.py:85, in AvaliacaoService._avaliar_modelo(self, nome_arquivo, nome_modelo, ground_truth_mask, mask_modelo, score_mask_modelo, segmentacao)
#      69 perimetro = Perimetro(
#      70     nome_arquivo=nome_arquivo,
#      71     mask_array=mask_modelo,
#      72     modelo=nome_modelo,
#      73 ).calcular()
#      74 iou = IoU(
#      75     nome_arquivo=nome_arquivo,
#      76     mask_modelo=mask_modelo,
#      77     mask_ground_truth=ground_truth_mask,
#      78     modelo=nome_modelo,
#      79 ).calcular()
#      80 auprc = AUPRC(
#      81     nome_arquivo=nome_arquivo,
#      82     score_mask=score_mask_modelo,
#      83     ground_truth_mask=ground_truth_mask,
#      84     modelo=nome_modelo,
# ---> 85 ).calcular()
#      87 registro = segmentacao or Segmentacao(
#      88     nome_arquivo=nome_arquivo,
#      89     nome_modelo=nome_modelo,
#      90 )
#      91 registro.area = float(area)
#
# File ~/projeto-bufalos/worktrees/auprc-binarizacao/src/binarizacao/metricas/auprc.py:29, in AUPRC.calcular(self)
#      26 if total_positivos == 0:
#      27     return 0.0
# ---> 29 ordem_descendente = np.argsort(-scores, kind="mergesort")
#      30 ground_truth_ordenado = ground_truth[ordem_descendente]
#      31 scores_ordenados = scores[ordem_descendente]
#
# File ~/projeto-bufalos/worktrees/auprc-binarizacao/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:1213, in argsort(a, axis, kind, order, stable)
#    1100 @array_function_dispatch(_argsort_dispatcher)
#    1101 def argsort(a, axis=-1, kind=None, order=None, *, stable=None):
#    1102     """
#    1103     Returns the indices that would sort an array.
#    1104
#    (...)   1211
#    1212     """
# -> 1213     return _wrapfunc(
#    1214         a, 'argsort', axis=axis, kind=kind, order=order, stable=stable
#    1215     )
#
# File ~/projeto-bufalos/worktrees/auprc-binarizacao/.venv/lib/python3.13/site-packages/numpy/_core/fromnumeric.py:54, in _wrapfunc(obj, method, *args, **kwds)
#      51     return _wrapit(obj, method, *args, **kwds)
#      53 try:
# ---> 54     return bound(*args, **kwds)
#      55 except TypeError:
#      56     # A TypeError occurs if the object does have such a method in its
#      57     # class, but its signature is not identical to that of NumPy's. This
#    (...)     61     # Call _wrapit from within the except clause to ensure a potential
#      62     # exception has a traceback chain.
#      63     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Resumo rapido
#
# Confere quantas imagens e segmentacoes ficaram com metricas persistidas.

# %%
imagens = avaliacao_controller.imagem_repository.list()
imagens_com_ground_truth = sum(
    1
    for imagem in imagens
    if imagem.ground_truth_binarizada is not None
    and imagem.ground_truth_binarizada.area is not None
    and imagem.ground_truth_binarizada.perimetro is not None
)
segmentacoes_avaliadas = sum(
    1
    for imagem in imagens
    for segmentacao in imagem.segmentacoes
    if segmentacao.area is not None
    and segmentacao.perimetro is not None
    and segmentacao.iou is not None
)

print(f"Imagens com ground truth avaliado: {imagens_com_ground_truth}")
print(f"Segmentacoes com metricas persistidas: {segmentacoes_avaliadas}")
print("Para explorar ranking e visualizacoes, siga para o notebook 04.")
